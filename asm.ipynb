# %%
import pandas as pd

# %%
df = pd.read_csv("OECD.TAD.ARPDSD_AGRI_ENVDF_AEI1.0-.A......csv")
df.head()
# Out:
#   STRUCTURE                           STRUCTURE_ID  \
# 0  DATAFLOW  OECD.TAD.ARP:DSD_AGRI_ENV@DF_AEI(1.0)
# 1  DATAFLOW  OECD.TAD.ARP:DSD_AGRI_ENV@DF_AEI(1.0)
# 2  DATAFLOW  OECD.TAD.ARP:DSD_AGRI_ENV@DF_AEI(1.0)
# 3  DATAFLOW  OECD.TAD.ARP:DSD_AGRI_ENV@DF_AEI(1.0)
# 4  DATAFLOW  OECD.TAD.ARP:DSD_AGRI_ENV@DF_AEI(1.0)
#
#                             STRUCTURE_NAME ACTION REF_AREA Reference area  \
# 0  Agri-environmental indicators: all data      I      AUT        Austria
# 1  Agri-environmental indicators: all data      I      AUT        Austria
# 2  Agri-environmental indicators: all data      I      AUT        Austria
# 3  Agri-environmental indicators: all data      I      AUT        Austria
# 4  Agri-environmental indicators: all data      I      AUT        Austria
#
#   FREQ Frequency of observation MEASURE  \
# 0    A                   Annual     BRN
# 1    A                   Annual     BRN
# 2    A                   Annual     BRN
# 3    A                   Annual     BRN
# ...

# %%
df = df.drop(columns=['STRUCTURE', 'STRUCTURE_ID', 'STRUCTURE_NAME', 'ACTION', 'Observation value', 'Decimals', 'Base period', 'FREQ', 'Frequency of observation', 'Time period', 'DECIMALS', 'BASE_PER'])

# %%
df.head()
# Out:
#   REF_AREA Reference area MEASURE  \
# 0      AUT        Austria     BRN
# 1      AUT        Austria     BRN
# 2      AUT        Austria     BRN
# 3      AUT        Austria     BRN
# 4      AUT        Austria     BRN
#
#                                              Measure EROSION_LEVEL  \
# 0  Nutrient removal by crop residues burned on th...            _Z
# 1  Nutrient removal by crop residues burned on th...            _Z
# 2  Nutrient removal by crop residues burned on th...            _Z
# 3  Nutrient removal by crop residues burned on th...            _Z
# 4  Nutrient removal by crop residues burned on th...            _Z
#
#   Erosion risk level WATER_TYPE      Water type   NUTRIENTS   Nutrients  \
# 0     Not applicable         _Z  Not applicable  PHOSPHORUS  Phosphorus
# 1     Not applicable         _Z  Not applicable  PHOSPHORUS  Phosphorus
# 2     Not applicable         _Z  Not applicable  PHOSPHORUS  Phosphorus
# ...

# %%
for i in df.columns:
    print(i, df[i].unique())
# Out:
# REF_AREA ['AUT' 'CZE' 'FIN' 'FRA' 'HUN' 'IRL' 'NLD' 'NOR' 'POL' 'PRT' 'SVK' 'SVN'
#  'SWE' 'GBR' 'HRV' 'ROU' 'ITA' 'LVA' 'BGR' 'ESP' 'CAN' 'COL' 'EST' 'LTU'
#  'ISL' 'EU28' 'MLT' 'DNK' 'GRC' 'LUX' 'CYP' 'BEL' 'DEU' 'CHE' 'AUS' 'CHL'
#  'ISR' 'JPN' 'KOR' 'MEX' 'TUR' 'USA' 'ARG' 'CRI' 'BRA' 'CHN' 'IND' 'IDN'
#  'KAZ' 'RUS' 'ZAF' 'UKR' 'VNM' 'EU27' 'NZL' 'EU' 'EU27_2020' 'PHL' 'PER'
#  'BE2' 'BE3']
# Reference area ['Austria' 'Czechia' 'Finland' 'France' 'Hungary' 'Ireland' 'Netherlands'
#  'Norway' 'Poland' 'Portugal' 'Slovak Republic' 'Slovenia' 'Sweden'
#  'United Kingdom' 'Croatia' 'Romania' 'Italy' 'Latvia' 'Bulgaria' 'Spain'
#  'Canada' 'Colombia' 'Estonia' 'Lithuania' 'Iceland'
#  'European Union (28 countries)' 'Malta' 'Denmark' 'Greece' 'Luxembourg'
#  'Cyprus' 'Belgium' 'Germany' 'Switzerland' 'Australia' 'Chile' 'Israel'
#  'Japan' 'Korea' 'Mexico' 'Türkiye' 'United States' 'Argentina'
#  'Costa Rica' 'Brazil' 'China (People’s Republic of)' 'India' 'Indonesia'
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53592 entries, 0 to 53591
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   REF_AREA            53592 non-null  object
#  1   Reference area      53592 non-null  object
#  2   MEASURE             53592 non-null  object
#  3   Measure             53592 non-null  object
#  4   EROSION_LEVEL       53592 non-null  object
#  5   Erosion risk level  53592 non-null  object
#  6   WATER_TYPE          53592 non-null  object
#  7   Water type          53592 non-null  object
#  8   NUTRIENTS           53592 non-null  object
#  9   Nutrients           53592 non-null  object
#  10  UNIT_MEASURE        53592 non-null  object
#  11  Unit of measure     53592 non-null  object
#  12  TIME_PERIOD         53592 non-null  int64
#  13  OBS_VALUE           53592 non-null  float64
#  14  OBS_STATUS          53592 non-null  object
# ...

# %%
df.isnull().any()
# Out:
# REF_AREA              False
# Reference area        False
# MEASURE               False
# Measure               False
# EROSION_LEVEL         False
# Erosion risk level    False
# WATER_TYPE            False
# Water type            False
# NUTRIENTS             False
# Nutrients             False
# UNIT_MEASURE          False
# Unit of measure       False
# TIME_PERIOD           False
# OBS_VALUE             False
# OBS_STATUS            False
# Observation status    False
# UNIT_MULT             False
# Unit multiplier       False
# dtype: bool

# %%
df.isna().any()
# Out:
# REF_AREA              False
# Reference area        False
# MEASURE               False
# Measure               False
# EROSION_LEVEL         False
# Erosion risk level    False
# WATER_TYPE            False
# Water type            False
# NUTRIENTS             False
# Nutrients             False
# UNIT_MEASURE          False
# Unit of measure       False
# TIME_PERIOD           False
# OBS_VALUE             False
# OBS_STATUS            False
# Observation status    False
# UNIT_MULT             False
# Unit multiplier       False
# dtype: bool
