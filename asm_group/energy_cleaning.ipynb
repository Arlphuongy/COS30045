# %%
import pandas as pd

# %%
df = pd.read_csv("OECD_dashboard/data/energy.csv")
df.head()
# Out:
#   STRUCTURE                             STRUCTURE_ID STRUCTURE_NAME ACTION  \
# 0  DATAFLOW  OECD.TAD.ARP:DSD_AGRI_ENV@DF_AGNRJ(1.0)     Energy use      I
# 1  DATAFLOW  OECD.TAD.ARP:DSD_AGRI_ENV@DF_AGNRJ(1.0)     Energy use      I
# 2  DATAFLOW  OECD.TAD.ARP:DSD_AGRI_ENV@DF_AGNRJ(1.0)     Energy use      I
# 3  DATAFLOW  OECD.TAD.ARP:DSD_AGRI_ENV@DF_AGNRJ(1.0)     Energy use      I
# 4  DATAFLOW  OECD.TAD.ARP:DSD_AGRI_ENV@DF_AGNRJ(1.0)     Energy use      I
#
#   REF_AREA Reference area FREQ Frequency of observation   MEASURE  \
# 0      VNM       Viet Nam    A                   Annual    TOTNRJ
# 1      VNM       Viet Nam    A                   Annual  TOTNRJAG
# 2      VNM       Viet Nam    A                   Annual  TOTNRJAG
# 3      AUS      Australia    A                   Annual    TOTNRJ
# 4      AUS      Australia    A                   Annual    TOTNRJ
#
#                              Measure  ...  OBS_VALUE Observation value  \
# ...

# %%
for i in df.columns:
    print(i, df[i].unique())
# Out:
# STRUCTURE ['DATAFLOW']
# STRUCTURE_ID ['OECD.TAD.ARP:DSD_AGRI_ENV@DF_AGNRJ(1.0)']
# STRUCTURE_NAME ['Energy use']
# ACTION ['I']
# REF_AREA ['VNM' 'AUS' 'AUT' 'CAN' 'BEL' 'CRI' 'COL' 'CHL' 'DNK' 'CZE' 'FIN' 'EST'
#  'DEU' 'FRA' 'ISL' 'HUN' 'GRC' 'ISR' 'IRL' 'JPN' 'ITA' 'LTU' 'LVA' 'KOR'
#  'MEX' 'LUX' 'NZL' 'NLD' 'POL' 'NOR' 'SVN' 'SVK' 'PRT' 'SWE' 'ESP' 'TUR'
#  'CHE' 'USA' 'GBR' 'ARG' 'EU27_2020' 'EU28' 'BGR' 'BRA' 'HRV' 'CHN' 'IND'
#  'CYP' 'MLT' 'KAZ' 'IDN' 'PHL' 'PER' 'RUS' 'ROU' 'UKR' 'ZAF']
# Reference area ['Viet Nam' 'Australia' 'Austria' 'Canada' 'Belgium' 'Costa Rica'
#  'Colombia' 'Chile' 'Denmark' 'Czechia' 'Finland' 'Estonia' 'Germany'
#  'France' 'Iceland' 'Hungary' 'Greece' 'Israel' 'Ireland' 'Japan' 'Italy'
#  'Lithuania' 'Latvia' 'Korea' 'Mexico' 'Luxembourg' 'New Zealand'
#  'Netherlands' 'Poland' 'Norway' 'Slovenia' 'Slovak Republic' 'Portugal'
#  'Sweden' 'Spain' 'Türkiye' 'Switzerland' 'United States' 'United Kingdom'
# ...

# %%
df = df.drop(columns=['STRUCTURE', 'STRUCTURE_ID', 'STRUCTURE_NAME', 'ACTION', 'Observation value', 'Decimals', 'Base period', 'FREQ', 'Frequency of observation', 'Time period', 'DECIMALS', 'BASE_PER', 'EROSION_LEVEL', 'Erosion risk level', 'NUTRIENTS', 'Nutrients'])

# %%
df = df.drop(columns=['MEASURE', 'WATER_TYPE', 'OBS_STATUS', 'UNIT_MULT', 'UNIT_MEASURE', 'Water type'])

# %%
df = df.rename(columns={
    'REF_AREA': 'CountryCode',
    'TIME_PERIOD': 'Year',
    'OBS_VALUE': 'Value'
})

# %%
for i in df.columns:
    print(i, df[i].unique())
# Out:
# CountryCode ['VNM' 'AUS' 'AUT' 'CAN' 'BEL' 'CRI' 'COL' 'CHL' 'DNK' 'CZE' 'FIN' 'EST'
#  'DEU' 'FRA' 'ISL' 'HUN' 'GRC' 'ISR' 'IRL' 'JPN' 'ITA' 'LTU' 'LVA' 'KOR'
#  'MEX' 'LUX' 'NZL' 'NLD' 'POL' 'NOR' 'SVN' 'SVK' 'PRT' 'SWE' 'ESP' 'TUR'
#  'CHE' 'USA' 'GBR' 'ARG' 'EU27_2020' 'EU28' 'BGR' 'BRA' 'HRV' 'CHN' 'IND'
#  'CYP' 'MLT' 'KAZ' 'IDN' 'PHL' 'PER' 'RUS' 'ROU' 'UKR' 'ZAF']
# Reference area ['Viet Nam' 'Australia' 'Austria' 'Canada' 'Belgium' 'Costa Rica'
#  'Colombia' 'Chile' 'Denmark' 'Czechia' 'Finland' 'Estonia' 'Germany'
#  'France' 'Iceland' 'Hungary' 'Greece' 'Israel' 'Ireland' 'Japan' 'Italy'
#  'Lithuania' 'Latvia' 'Korea' 'Mexico' 'Luxembourg' 'New Zealand'
#  'Netherlands' 'Poland' 'Norway' 'Slovenia' 'Slovak Republic' 'Portugal'
#  'Sweden' 'Spain' 'Türkiye' 'Switzerland' 'United States' 'United Kingdom'
#  'Argentina' 'European Union (27 countries from 01/02/2020)'
#  'European Union (28 countries)' 'Bulgaria' 'Brazil' 'Croatia'
# ...

# %%
df.head()
# Out:
#   CountryCode Reference area                            Measure  \
# 0         VNM       Viet Nam     Total final energy consumption
# 1         VNM       Viet Nam  Direct on-farm energy consumption
# 2         VNM       Viet Nam  Direct on-farm energy consumption
# 3         AUS      Australia     Total final energy consumption
# 4         AUS      Australia     Total final energy consumption
#
#             Unit of measure  Year      Value Observation status  \
# 0  Tonnes of oil equivalent  1995  19831.570       Normal value
# 1  Tonnes of oil equivalent  1995    375.250       Normal value
# 2  Tonnes of oil equivalent  1996    408.331       Normal value
# 3  Tonnes of oil equivalent  1986  49432.618       Normal value
# 4  Tonnes of oil equivalent  1987  50548.281       Normal value
#
#   Unit multiplier
# 0       Thousands
# 1       Thousands
# 2       Thousands
# 3       Thousands
# 4       Thousands

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4198 entries, 0 to 4197
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CountryCode         4198 non-null   object
#  1   Reference area      4198 non-null   object
#  2   Measure             4198 non-null   object
#  3   Unit of measure     4198 non-null   object
#  4   Year                4198 non-null   int64
#  5   Value               4108 non-null   float64
#  6   Observation status  4198 non-null   object
#  7   Unit multiplier     4198 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 262.5+ KB

# %%
df.isnull().any()
# Out:
# CountryCode           False
# Reference area        False
# Measure               False
# Unit of measure       False
# Year                  False
# Value                  True
# Observation status    False
# Unit multiplier       False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = df.dropna(subset=['Value'])

# %%
output_path = "D:\\khoane\\Swin\\5-2025\\COS30045\\COS30045\\assignment_group\\OECD_dashboard\\data\\energy_cleaned.csv"
df.to_csv(output_path, index=False)
